# %% [markdown]
# # Destination Prediction Exploration
#
# The reproducible training workflow lives in `../train.py`.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
data = pd.read_csv(ROOT / 'data/raw/location_dataset.csv')
data.head()

# %%
routes = data.groupby(['latStart', 'lonStart', 'latEnd', 'lonEnd']).size().sort_values(ascending=False)
print(f'Rows: {len(data):,}')
print(f'Unique routes: {len(routes):,}')
routes.head(10)
